# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
from claude_agent_sdk import query

async for message in query(prompt="What was the capital of korea"):
    print(message, "\n\n")
# Out:
# SystemMessage(subtype='init', data={'type': 'system', 'subtype': 'init', 'cwd': '/Users/gimjeongtae/Desktop/MyProject/nomadcoder-ai-agent-study/claude-agent-sdk', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4', 'tools': ['Task', 'AskUserQuestion', 'Bash', 'CronCreate', 'CronDelete', 'CronList', 'DesignSync', 'Edit', 'EnterPlanMode', 'EnterWorktree', 'ExitPlanMode', 'ExitWorktree', 'Monitor', 'NotebookEdit', 'PushNotification', 'Read', 'ScheduleWakeup', 'Skill', 'TaskCreate', 'TaskGet', 'TaskList', 'TaskOutput', 'TaskStop', 'TaskUpdate', 'WebFetch', 'WebSearch', 'Workflow', 'Write'], 'mcp_servers': [], 'model': '~anthropic/claude-sonnet-latest[1m]', 'permissionMode': 'default', 'slash_commands': ['deep-research', 'design-sync', 'update-config', 'verify', 'debug', 'code-review', 'simplify', 'batch', 'fewer-permission-prompts', 'loop', 'claude-api', 'run', 'run-skill-generator', 'clear', 'compact', 'context', 'heapdump', 'init', 'reload-skills', 'review', 'security-review', 'usage', 'insights', 'goal', 'team-onboarding'], 'apiKeySource': 'none', 'claude_code_version': '2.1.175', 'output_style': 'default', 'agents': ['claude', 'Explore', 'general-purpose', 'Plan', 'statusline-setup'], 'skills': ['deep-research', 'design-sync', 'update-config', 'verify', 'debug', 'code-review', 'simplify', 'batch', 'fewer-permission-prompts', 'loop', 'claude-api', 'run', 'run-skill-generator'], 'plugins': [], 'analytics_disabled': False, 'product_feedback_disabled': False, 'uuid': 'd13f7a37-9cb4-4627-87ab-04f215b45766', 'memory_paths': {'auto': '/Users/gimjeongtae/.claude/projects/-Users-gimjeongtae-Desktop-MyProject-nomadcoder-ai-agent-study/memory/'}, 'fast_mode_state': 'off'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 1, 'estimated_tokens_delta': 1, 'uuid': 'e99f7543-0c9e-4924-a2f7-d8bdfd6977d1', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 10, 'estimated_tokens_delta': 9, 'uuid': '3c4bbe4b-f033-4cf2-a648-c49caf1d1792', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 19, 'estimated_tokens_delta': 9, 'uuid': '71ecded9-d88b-4ca3-800b-d349259d898a', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 22, 'estimated_tokens_delta': 3, 'uuid': 'e2a27202-2546-40f6-b432-dad60b3a3438', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 23, 'estimated_tokens_delta': 1, 'uuid': '6e10848c-5ac9-40a3-b0d3-e8baefc93180', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 26, 'estimated_tokens_delta': 3, 'uuid': '73c0d6ab-4a50-4281-be15-11e4b0e43bc9', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 30, 'estimated_tokens_delta': 4, 'uuid': 'c8e3bcdf-cce3-487e-bc3e-bf3fffeeb83e', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 31, 'estimated_tokens_delta': 1, 'uuid': 'e9a2de70-b4ab-410a-b582-df8f740073ba', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 33, 'estimated_tokens_delta': 2, 'uuid': '3c24178b-f78e-4e92-982e-6373cd55ef2f', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 35, 'estimated_tokens_delta': 2, 'uuid': 'cdf7663d-8c96-488f-b8af-5a87e5391e8d', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 38, 'estimated_tokens_delta': 3, 'uuid': '3b5ce396-1636-4746-b2da-d0a95f8c2bc0', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 39, 'estimated_tokens_delta': 1, 'uuid': '0058785d-a8a1-45f8-b580-ed8c360e68f0', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 44, 'estimated_tokens_delta': 5, 'uuid': '1ed0cf43-6e69-4b93-bc53-3684613d3134', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 46, 'estimated_tokens_delta': 2, 'uuid': 'db1ac904-8d4b-4367-a1db-b7fb00fd627c', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 47, 'estimated_tokens_delta': 1, 'uuid': '05cb27f2-eb2e-4505-a9c0-e7175e5897a4', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 48, 'estimated_tokens_delta': 1, 'uuid': '6411170a-a206-42fc-94c6-74fdd73afa91', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 51, 'estimated_tokens_delta': 3, 'uuid': '479f84c6-a151-46ec-8fcf-51e9dc53ac34', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 54, 'estimated_tokens_delta': 3, 'uuid': 'a84a4d6d-3335-47c9-bc74-d00cdfd7a459', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 58, 'estimated_tokens_delta': 4, 'uuid': 'e01f44c3-3ec3-46fe-a6d3-1557d643f0c9', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 59, 'estimated_tokens_delta': 1, 'uuid': '72c47bc2-f800-4bd6-b9f7-4502048cbcca', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 60, 'estimated_tokens_delta': 1, 'uuid': '125dff82-b2c0-4e10-8a7c-2969352689e4', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 65, 'estimated_tokens_delta': 5, 'uuid': '5b31e7e4-0c92-41a2-a37e-c3d3c04b15b7', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 70, 'estimated_tokens_delta': 5, 'uuid': '7fe48f37-b520-452c-8383-057954237743', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 71, 'estimated_tokens_delta': 1, 'uuid': '582bdd38-85c2-4ebd-b16b-804ff37b6223', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 72, 'estimated_tokens_delta': 1, 'uuid': '92b8ffe1-3c7a-413d-8473-ffbe0778b47a', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 77, 'estimated_tokens_delta': 5, 'uuid': '08d2303d-adeb-4d04-9f32-5f496303705d', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 78, 'estimated_tokens_delta': 1, 'uuid': '92085d98-1b53-466e-9547-02da6513ba15', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 81, 'estimated_tokens_delta': 3, 'uuid': '62e28844-93a0-4e86-9ba9-69ec9b163f76', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 82, 'estimated_tokens_delta': 1, 'uuid': '72dd15b7-23d0-4f41-8252-5d89c8639de4', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 84, 'estimated_tokens_delta': 2, 'uuid': '80865187-f372-48cd-9bd7-55cb9e46d013', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 87, 'estimated_tokens_delta': 3, 'uuid': 'd829c45b-611e-4070-a2aa-c6f255fbba38', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 88, 'estimated_tokens_delta': 1, 'uuid': 'e38dca7b-44ae-4dc4-a7e8-fb4efc8a3c14', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 91, 'estimated_tokens_delta': 3, 'uuid': 'e8df40a2-1e53-4cc4-ac56-c7feca28da00', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 92, 'estimated_tokens_delta': 1, 'uuid': 'b8dcbad3-3851-4d39-8bf2-1a94bac23a5f', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 94, 'estimated_tokens_delta': 2, 'uuid': '6dbb1013-c744-4da0-8069-31b491938230', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 97, 'estimated_tokens_delta': 3, 'uuid': '09d16b59-4900-4841-ae61-a570be216ff4', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 101, 'estimated_tokens_delta': 4, 'uuid': '3cb06711-209c-4e13-a985-8ca5f6382340', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 102, 'estimated_tokens_delta': 1, 'uuid': '412105e7-493c-4cec-af3f-c8ff08553b42', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 103, 'estimated_tokens_delta': 1, 'uuid': '1c330a9f-06d1-49b6-95d2-fd35ec2041e3', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 104, 'estimated_tokens_delta': 1, 'uuid': '3ebf6602-4973-4ff8-9fe6-02214626c9c7', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 105, 'estimated_tokens_delta': 1, 'uuid': '2374f326-ed47-4952-87ec-98b05fc261f5', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 113, 'estimated_tokens_delta': 8, 'uuid': '321649eb-8130-4e02-85c4-08c6561c8671', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 117, 'estimated_tokens_delta': 4, 'uuid': '97682e38-0ae1-47e2-a4ca-de0330810248', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 121, 'estimated_tokens_delta': 4, 'uuid': 'c85c1ed4-848c-4daa-be11-1b8e0e9484c3', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 123, 'estimated_tokens_delta': 2, 'uuid': '33b43e0a-9100-42a7-81c1-3b1dabf83d74', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 124, 'estimated_tokens_delta': 1, 'uuid': 'ba539dd9-73d6-45de-95f5-87e8d4ad8b1f', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 127, 'estimated_tokens_delta': 3, 'uuid': 'ed01f467-a422-4f21-aca5-276513ca94fd', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 129, 'estimated_tokens_delta': 2, 'uuid': 'c6ae2cce-efaf-41b6-8ac5-d03eefa6432d', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 130, 'estimated_tokens_delta': 1, 'uuid': 'c456c7c3-d9cb-47e8-b4fa-4df3e7810478', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 131, 'estimated_tokens_delta': 1, 'uuid': '40eb00e6-c408-4413-8c99-6615134ea114', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 134, 'estimated_tokens_delta': 3, 'uuid': '282f9cba-cde1-402b-baa8-c34bf4a50d5c', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 136, 'estimated_tokens_delta': 2, 'uuid': '19247bf5-5203-4bc3-837a-01acc582a333', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 137, 'estimated_tokens_delta': 1, 'uuid': '92be8d69-9aaf-4945-ad2b-ba8986e4534b', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 138, 'estimated_tokens_delta': 1, 'uuid': 'df657d28-c898-4c1b-93b5-1fe4cc3780fd', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 139, 'estimated_tokens_delta': 1, 'uuid': '7cfc2dc1-7326-44ca-a778-2f7f4a773dcd', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 141, 'estimated_tokens_delta': 2, 'uuid': '49397f96-2ea6-46e4-801a-b782ee55ff65', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 144, 'estimated_tokens_delta': 3, 'uuid': '6b41e615-71d0-47e4-8218-af57a3fd09c0', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 147, 'estimated_tokens_delta': 3, 'uuid': '31745e26-6d8e-413d-b3cd-f6444e6ae2ae', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 152, 'estimated_tokens_delta': 5, 'uuid': 'd270b047-b40b-4442-b741-c14fd3058825', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 154, 'estimated_tokens_delta': 2, 'uuid': 'e4a1d442-e19f-460f-a7e8-7cb20a2586be', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 158, 'estimated_tokens_delta': 4, 'uuid': '878800d1-983d-4bff-98df-96aeff856130', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 160, 'estimated_tokens_delta': 2, 'uuid': 'b829b625-b11e-4c7d-9bd5-d4d9043feff4', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 164, 'estimated_tokens_delta': 4, 'uuid': '313d0e63-ef99-40bd-b780-2af29213c951', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 165, 'estimated_tokens_delta': 1, 'uuid': 'c87d2d9d-4a6d-4e96-8b99-9461db9faa6f', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 166, 'estimated_tokens_delta': 1, 'uuid': '36eadf79-da91-4651-831c-aeeeb1cd34fd', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 170, 'estimated_tokens_delta': 4, 'uuid': '26a316bb-1d35-4e6e-aede-6dbc7806406c', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 172, 'estimated_tokens_delta': 2, 'uuid': 'b44b527c-8cc9-4040-b5a4-a6608528cde6', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 173, 'estimated_tokens_delta': 1, 'uuid': '9931e720-e329-4f07-b828-03f2e9fdecc5', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 174, 'estimated_tokens_delta': 1, 'uuid': 'a3004301-e37c-4d58-ab04-b9ee5540bfc5', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 176, 'estimated_tokens_delta': 2, 'uuid': 'b716da27-58d5-4151-8398-c18abdec202c', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 179, 'estimated_tokens_delta': 3, 'uuid': '37a7f94d-92b3-4a07-88b8-3abc46a3e112', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 180, 'estimated_tokens_delta': 1, 'uuid': '61525262-044e-4df4-b090-84e16309b273', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 181, 'estimated_tokens_delta': 1, 'uuid': 'deb01e57-2f11-4f27-bf74-a9929042d39a', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 184, 'estimated_tokens_delta': 3, 'uuid': '94e2c35d-8db0-4edc-95c7-542bc075ca80', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 192, 'estimated_tokens_delta': 8, 'uuid': 'b181d1a0-c74e-42b3-9ff9-d64915968443', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 195, 'estimated_tokens_delta': 3, 'uuid': '22e313ad-f17e-4d3e-8bdc-475c8a9dde3c', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 198, 'estimated_tokens_delta': 3, 'uuid': '7bbca2b1-b6da-49c2-9191-d938abcc1d99', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 200, 'estimated_tokens_delta': 2, 'uuid': '7c1e15b6-088f-4fc9-a735-3e21d4c75f43', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 205, 'estimated_tokens_delta': 5, 'uuid': '9c8fa451-cac1-44db-a726-7f554352ee80', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# SystemMessage(subtype='thinking_tokens', data={'type': 'system', 'subtype': 'thinking_tokens', 'estimated_tokens': 232, 'estimated_tokens_delta': 27, 'uuid': '8fe0023a-8cfb-4976-aa60-2eff18daf10b', 'session_id': 'a3b5c356-9b41-4723-85d6-2b96323fa1f4'})
#
#
# AssistantMessage(content=[ThinkingBlock(thinking='The user is asking about the capital of Korea. This is a straightforward historical/geographical question. Korea has been divided into North and South Korea since 1948. Let me answer this from my knowledge:\n\n- The capital of South Korea is Seoul (and has been historically the capital of the Korean peninsula for centuries, dating back to the Joseon Dynasty in 1394).\n- The capital of North Korea is Pyongyang.\n\nHistorically, before the division, Seoul (then called Hanseong or Keijō under Japanese occupation) was the capital. Before that, during the Goryeo Dynasty, the capital was Kaesong (now in North Korea).\nThis is straightforward factual information I can provide directly from my training data.', signature='...')], model='anthropic/claude-4.6-sonnet-20260217', parent_tool_use_id=None, error=None, usage={'input_tokens': 0, 'output_tokens': 0, 'cache_creation_input_tokens': None, 'cache_read_input_tokens': None, 'cache_creation': None, 'inference_geo': None, 'server_tool_use': None, 'service_tier': None, 'speed': 'standard'}, message_id='gen-1781275687-p3syS7gYriIMJE1hd0VV', stop_reason=None, session_id='a3b5c356-9b41-4723-85d6-2b96323fa1f4', uuid='616ff6d1-3882-4d03-8f7f-d9be53b3446a')
#
#
# AssistantMessage(content=[TextBlock(text="## Capital of Korea\n\nThe answer depends on the historical period and which Korea you mean:\n\n### Unified/Historical Korea\n- **Hanseong** (한성, modern-day **Seoul**) — capital of the **Joseon Dynasty** (1394–1897)\n- **Hanyang** was another name for the same city during that era\n- **Kaesong** (개성) — capital of the **Goryeo Dynasty** (918–1392), now located in present-day North Korea\n- **Gyeongju** (경주) — capital of the **Silla Kingdom** (57 BC–935 AD)\n\n### Modern Korea (post-1948 division)\n- 🇰🇷 **Seoul** — capital of **South Korea** (Republic of Korea)\n- 🇰🇵 **Pyongyang** — capital of **North Korea** (Democratic People's Republic of Korea)\n\nSeoul has been the dominant political and cultural center of the Korean peninsula for over **600 years**, making it the most historically significant answer to your question.")], model='anthropic/claude-4.6-sonnet-20260217', parent_tool_use_id=None, error=None, usage={'input_tokens': 0, 'output_tokens': 0, 'cache_creation_input_tokens': None, 'cache_read_input_tokens': None, 'cache_creation': None, 'inference_geo': None, 'server_tool_use': None, 'service_tier': None, 'speed': 'standard'}, message_id='gen-1781275687-p3syS7gYriIMJE1hd0VV', stop_reason=None, session_id='a3b5c356-9b41-4723-85d6-2b96323fa1f4', uuid='ea594c95-b8a6-410a-821c-cef362ebed88')
#
#
# AssistantMessage(content=[], model='anthropic/claude-4.6-sonnet-20260217', parent_tool_use_id=None, error=None, usage={'input_tokens': 0, 'output_tokens': 0, 'cache_creation_input_tokens': None, 'cache_read_input_tokens': None, 'cache_creation': None, 'inference_geo': None, 'server_tool_use': None, 'service_tier': None, 'speed': 'standard'}, message_id='gen-1781275687-p3syS7gYriIMJE1hd0VV', stop_reason=None, session_id='a3b5c356-9b41-4723-85d6-2b96323fa1f4', uuid='ed7abd7f-0512-47cc-97da-d87d6b80cf2e')
#
#
# ResultMessage(subtype='success', duration_ms=12774, duration_api_ms=14861, is_error=False, num_turns=1, session_id='a3b5c356-9b41-4723-85d6-2b96323fa1f4', stop_reason='end_turn', total_cost_usd=0.20083624999999997, usage={'input_tokens': 3, 'cache_creation_input_tokens': 30001, 'cache_read_input_tokens': 0, 'output_tokens': 432, 'server_tool_use': {'web_search_requests': 0, 'web_fetch_requests': 0}, 'service_tier': 'standard', 'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'inference_geo': '', 'iterations': [], 'speed': 'standard'}, result='', structured_output=None, model_usage={'~anthropic/claude-sonnet-latest': {'inputTokens': 443, 'outputTokens': 12, 'cacheReadInputTokens': 0, 'cacheCreationInputTokens': 0, 'webSearchRequests': 0, 'costUSD': 0.002515, 'contextWindow': 200000, 'maxOutputTokens': 32000}, '~anthropic/claude-sonnet-latest[1m]': {'inputTokens': 3, 'outputTokens': 432, 'cacheReadInputTokens': 0, 'cacheCreationInputTokens': 30001, 'webSearchRequests': 0, 'costUSD': 0.19832124999999998, 'contextWindow': 1000000, 'maxOutputTokens': 32000}}, permission_denials=[], deferred_tool_use=None, errors=None, api_error_status=None, uuid='f4b75930-de9a-46ca-9574-0756484dd1e7')

# %%
from claude_agent_sdk import (
    query,
    SystemMessage,
    AssistantMessage,
    ResultMessage,
    TextBlock
)


async for message in query(prompt="한국의 수도는 어디일까?"):
    if isinstance(message, SystemMessage):
        print("SystemMessage")
    elif isinstance(message, AssistantMessage):
        for block in message.content:
            if isinstance(block, TextBlock):
                print(f"AssistantMessage ={block.text}")
    elif isinstance(message, ResultMessage):
        print(f"ResultMessage ${message.total_cost_usd}")
# Out:
# SystemMessage
# AssistantMessage =한국의 수도는 **서울**입니다.
#
# 서울은 대한민국의 수도이자 최대 도시로, 약 **1,000만 명** 이상의 인구가 거주하고 있으며, 수도권(서울·경기·인천)을 포함하면 약 **2,600만 명** 이상이 살고 있는 세계 최대 도시권 중 하나입니다.
# ResultMessage $0.193465
